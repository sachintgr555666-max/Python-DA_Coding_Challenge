# %% [markdown]
# ## Day 2 – Pandas Basics
# Dataset: HR Employee Attrition
# Goal: Import, explore, update, delete, index and sort data.

# %%
import pandas as pd

# %% [markdown]
# ## Import dataset into a Pandas DataFrame

# %%
df = pd.read_excel("/content/HR-Employee-Attrition.xlsx")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# ## Explore columns

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ## Explore Series

# %%
print(df["Age"].head())
# Out:
# 0    41
# 1    49
# 2    37
# 3    33
# 4    27
# Name: Age, dtype: int64

# %% [markdown]
# ## Add a new column

# %%
df["IncomePerYear"] = df["MonthlyIncome"] * 12

# %%
print(df[["MonthlyIncome", "IncomePerYear"]].head())
# Out:
#    MonthlyIncome  IncomePerYear
# 0           5993          71916
# 1           5130          61560
# 2           2090          25080
# 3           2909          34908
# 4           3468          41616

# %% [markdown]
# ## Update a column

# %%
df["IncomePerYear"] = df["MonthlyIncome"] * 12

# %%
print(df["IncomePerYear"].head())
# Out:
# 0    71916
# 1    61560
# 2    25080
# 3    34908
# 4    41616
# Name: IncomePerYear, dtype: int64

# %% [markdown]
# ## Delete a column

# %%
df["TemporaryColumn"] = "Practice"

# %% [markdown]
# ## Delete rows using index

# %%
df_without_first_row = df.drop(index=0)

# %%
print("\nRows after deleting index 0:", df_without_first_row.shape[0])
# Out:
# Rows after deleting index 0: 1469

# %% [markdown]
# ## Set custom index

# %%
indexed_df = df.set_index("EmployeeNumber")

# %%
indexed_df.head()
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
# 4                37       Yes      Travel_Rarely       1373
# 5                33        No  Travel_Frequently       1392
# 7                27        No      Travel_Rarely        591
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# 4               Research & Development                 2          2
# 5               Research & Development                 3          4
# 7               Research & Development                 2          1
#
#                EducationField  EmployeeCount  EnvironmentSatisfaction  ...  \
# EmployeeNumber                                                         ...
# ...

# %% [markdown]
# ## Sort by MonthlyIncome

# %%
sorted_df = df.sort_values(by="MonthlyIncome", ascending=False)

# %%
print(sorted_df[["EmployeeNumber", "Age", "JobRole", "MonthlyIncome"]].head(10))
# Out:
#       EmployeeNumber  Age            JobRole  MonthlyIncome
# 190              259   52            Manager          19999
# 746             1035   41  Research Director          19973
# 851             1191   56            Manager          19943
# 165              226   50            Manager          19926
# 568              787   55            Manager          19859
# 918             1282   51            Manager          19847
# 749             1038   52            Manager          19845
# 1242            1740   40            Manager          19833
# 898             1255   43  Research Director          19740
# 956             1338   56            Manager          19717
